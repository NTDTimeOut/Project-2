# %%
import os
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Train Data

# %%
# Đường dẫn đến thư mục chứa dữ liệu
data_train_dir = "../Data_set/Data_train2/"


# Xác định các đặc trưng (features) và nhãn (labels)
features = ["Ax", "Ay", "Az", "Gx", "Gy", "Gz"]

# Chuẩn bị dữ liệu huấn luyện
train_data = []
train_labels = []

# Đọc dữ liệu từ thư mục Data_processing
for file_name in os.listdir(data_train_dir):
    if file_name.endswith("_0.csv"):
        label = 0  # Nhãn nữ
    elif file_name.endswith("_1.csv"):
        label = 1  # Nhãn nam
    else:
        continue

    file_path = os.path.join(data_train_dir, file_name)
    df = pd.read_csv(file_path)
    flattened_data = df[features].values.flatten()  # Chuyển đổi dữ liệu thành 2 chiều
    flattened_data = np.nan_to_num(flattened_data, nan=0.0, posinf=1.7976931348623157e+308, neginf=2.2250738585072014e-308)
    train_data.append(flattened_data)
    train_labels.append(label)

# Xây dựng mô hình 

# linear
linear_model = SVC(kernel='linear')
linear_model.fit(train_data, train_labels)

#poly
poly_model = SVC(kernel='poly')
poly_model.fit(train_data, train_labels)

#rbf
rbf_model = SVC(kernel='rbf')
rbf_model.fit(train_data, train_labels)

#sigmoid
sigmoid_model = SVC(kernel='sigmoid')
sigmoid_model.fit(train_data, train_labels)

#RF
rf_model = RandomForestClassifier()
rf_model.fit(train_data, train_labels)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Test Data

# %%
test_path = "../Data_set/Data_test2/"

test_data = []
test_filenames = []
test_labels = []

# Duyệt qua các tệp tin trong thư mục test_path
for filename in os.listdir(test_path):
    # Kiểm tra nếu tệp tin có đuôi .csv
    if filename.endswith(".csv"):
        file_path = os.path.join(test_path, filename)
        df = pd.read_csv(file_path)
        
        # Lấy dữ liệu từ 6 cột Ax, Ay, Az, Gx, Gy, Gz
        features = df[['Ax', 'Ay', 'Az', 'Gx', 'Gy', 'Gz']].values
        features = np.nan_to_num(features, nan=0.0, posinf=1.7976931348623157e+308, neginf=2.2250738585072014e-308)
        test_data.append(features)  # Thêm dữ liệu vào test_data
        test_filenames.append(filename)  # Thêm tên tệp tin vào test_filenames
        test_labels.append(0 if filename.endswith("_0.csv") else 1)  # Thêm nhãn vào test_labels (0: nữ, 1: nam)

test_data = np.array(test_data).reshape(len(test_data), -1)  # Chuyển đổi test_data thành mảng numpy 2D

# %% [markdown]
# # Linear

# %%
predictions = linear_model.predict(test_data)  # Dự đoán giới tính trên dữ liệu kiểm tra

# In kết quả dự đoán và tên tệp tin tương ứng
for filename, label, prediction in zip(test_filenames, test_labels, predictions):
    print("File:", filename)
    print("Dự đoán giới tính:", prediction)
    print("--------------------")

accuracy = accuracy_score(test_labels, predictions)  # Tính độ chính xác bằng cách so sánh nhãn thực tế và nhãn dự đoán
print("Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: {:.2f}%".format(accuracy * 100))
# Out:
# File: ID000104_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002630_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID002838_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002942_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID004636_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005431_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005639_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID008440_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID009443_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID009547_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID010002_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013635_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013843_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID014222_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014638_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014950_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID015953_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID016020_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID016124_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID017127_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID018650_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019029_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019341_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID019445_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID020212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID020732_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021527_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021631_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021735_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID022218_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID022322_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID024744_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID053643_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID054230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054334_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID054438_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID057863_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID057967_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058242_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058346_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058762_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058866_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID059973_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID061535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID063645_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID064960_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065131_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065859_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID065963_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066030_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066134_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066238_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066446_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066550_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066654_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066758_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066862_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID067969_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068036_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068348_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068452_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068556_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068660_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068764_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068972_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID069975_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070014_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070638_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070742_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071537_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071953_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID072540_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072748_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID073543_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID074130_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID101212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102215_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102319_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID103114_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID103218_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID105120_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106435_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID109132_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109236_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109964_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110211_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110419_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112009_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112113_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID113012_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID114951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID115122_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID115226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117128_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117232_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117752_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID119654_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120837_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120941_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID121424_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID125644_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID129552_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID130943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID131634_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID135022_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID139970_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID150219_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID150427_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150739_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150843_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID151430_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID153956_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID154023_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID156237_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID156341_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID157136_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID157240_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID158347_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159558_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159974_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID163126_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID163230_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID165236_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID167034_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169352_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169456_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID171330_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179042_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179562_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179666_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200106_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200210_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200314_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200938_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201525_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201733_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID202840_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204430_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204534_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID205641_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID207751_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID207855_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID208026_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID208962_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID211423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID211943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID215019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216126_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID216230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216334_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID216646_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216854_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217025_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217129_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217753_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217961_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID219239_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID220734_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221321_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221841_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221945_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223639_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223743_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223847_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224122_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224746_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224850_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224954_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID225021_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: 73.18%

# %% [markdown]
# # Poly

# %%
predictions = poly_model.predict(test_data)  # Dự đoán giới tính trên dữ liệu kiểm tra

# In kết quả dự đoán và tên tệp tin tương ứng
for filename, label, prediction in zip(test_filenames, test_labels, predictions):
    print("File:", filename)
    print("Dự đoán giới tính:", prediction)
    print("--------------------")

accuracy = accuracy_score(test_labels, predictions)  # Tính độ chính xác bằng cách so sánh nhãn thực tế và nhãn dự đoán
print("Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: {:.2f}%".format(accuracy * 100))
# Out:
# File: ID000104_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID002630_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002838_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002942_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID004636_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005431_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005639_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID008440_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009443_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009547_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID010002_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013635_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013843_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014222_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014638_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014950_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID015953_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID016020_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID016124_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID017127_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID018650_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019029_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019341_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID019445_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID020212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID020732_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021527_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021631_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021735_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID022218_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID022322_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID024744_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID053643_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054334_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054438_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID057863_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID057967_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID058242_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058346_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058762_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058866_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID059973_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID061535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID063645_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID064960_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID065131_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065963_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066030_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066134_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066238_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066446_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066550_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066654_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066758_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066862_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID067969_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068036_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068348_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068452_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068556_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068660_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068764_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068972_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID069975_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070014_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070638_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070742_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID071537_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071953_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072540_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072748_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID073543_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID074130_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID101212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102215_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102319_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID103114_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID103218_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID105120_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID106019_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID106435_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109132_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109236_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109964_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110211_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110419_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112009_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112113_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID113012_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID114951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID115122_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID115226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117128_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117232_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117752_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID119654_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120837_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID120941_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID121424_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID125644_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID129552_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID130943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID131634_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID135022_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID139970_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID150219_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150427_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150739_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150843_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID151430_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID153956_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID154023_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID156237_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID156341_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID157136_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID157240_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID158347_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID159558_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159974_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID163126_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID163230_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID165236_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID167034_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID169352_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169456_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID171330_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179042_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179562_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179666_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200106_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200210_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200314_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200938_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID201525_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201733_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID202840_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204430_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204534_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID205641_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID207751_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID207855_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID208026_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID208962_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID211423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID211943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID215019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216126_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216334_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216646_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216854_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217025_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217129_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217753_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217961_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID219239_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID220734_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID221321_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221841_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID221945_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223639_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223743_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223847_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224122_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224226_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224746_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224850_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224954_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID225021_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: 57.54%

# %% [markdown]
# # RBF

# %%
predictions = rbf_model.predict(test_data)  # Dự đoán giới tính trên dữ liệu kiểm tra

# In kết quả dự đoán và tên tệp tin tương ứng
for filename, label, prediction in zip(test_filenames, test_labels, predictions):
    print("File:", filename)
    print("Dự đoán giới tính:", prediction)
    print("--------------------")

accuracy = accuracy_score(test_labels, predictions)  # Tính độ chính xác bằng cách so sánh nhãn thực tế và nhãn dự đoán
print("Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: {:.2f}%".format(accuracy * 100))
# Out:
# File: ID000104_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID002630_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002838_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID002942_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID004636_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005431_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005639_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID008440_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009443_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009547_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID010002_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013635_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013843_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014222_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014638_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014950_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID015953_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID016020_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID016124_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID017127_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID018650_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019029_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019341_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID019445_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID020212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID020732_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021527_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021631_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021735_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID022218_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID022322_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID024744_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID053643_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054334_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054438_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID057863_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID057967_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058242_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058346_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058762_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058866_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID059973_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID061535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID063645_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID064960_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID065131_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065963_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066030_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066134_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066238_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066446_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066550_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066654_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066758_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066862_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID067969_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068036_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068348_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068452_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068556_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068660_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068764_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068972_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID069975_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070014_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070638_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070742_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID071537_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071953_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072540_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072748_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID073543_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID074130_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID101212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102215_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102319_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID103114_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID103218_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID105120_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID106019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106435_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109132_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID109236_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109964_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110211_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110419_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112009_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID112113_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID113012_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID114951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID115122_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID115226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117128_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117232_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117752_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID119654_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120837_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120941_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID121424_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID125644_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID129552_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID130943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID131634_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID135022_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID139970_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID150219_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150427_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150739_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150843_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID151430_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID153956_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID154023_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID156237_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID156341_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID157136_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID157240_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID158347_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID159558_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159974_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID163126_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID163230_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID165236_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID167034_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID169352_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169456_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID171330_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179042_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179562_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179666_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200106_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200210_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200314_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200938_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201525_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201733_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID202840_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204430_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204534_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID205641_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID207751_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID207855_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID208026_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID208962_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID211423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID211943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID215019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216126_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216334_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216646_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216854_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217025_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217129_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217753_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217961_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID219239_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID220734_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID221321_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221841_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID221945_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223639_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223743_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223847_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224122_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224226_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224746_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224850_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224954_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID225021_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: 55.31%

# %% [markdown]
# # Sigmoid

# %%
predictions = sigmoid_model.predict(test_data)  # Dự đoán giới tính trên dữ liệu kiểm tra

# In kết quả dự đoán và tên tệp tin tương ứng
for filename, label, prediction in zip(test_filenames, test_labels, predictions):
    print("File:", filename)
    print("Dự đoán giới tính:", prediction)
    print("--------------------")

accuracy = accuracy_score(test_labels, predictions)  # Tính độ chính xác bằng cách so sánh nhãn thực tế và nhãn dự đoán
print("Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: {:.2f}%".format(accuracy * 100))
# Out:
# File: ID000104_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002630_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002838_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002942_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID004636_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005431_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005639_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID008440_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID009443_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009547_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID009859_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID010002_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID013635_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID013843_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014222_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014638_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014950_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID015953_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID016020_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID016124_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID017127_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID018650_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019029_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID019341_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019445_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID020212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID020732_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021527_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021631_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021735_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021943_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID022218_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID022322_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID024744_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID053643_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID054230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054334_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID054438_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID057863_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID057967_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID058242_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID058346_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID058762_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID058866_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID059973_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID061535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID063645_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID064960_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065131_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065963_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066030_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066134_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066238_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066446_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066550_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066654_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066758_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066862_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID067969_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068036_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068348_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068452_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068556_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068660_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068764_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068972_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID069975_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070014_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070222_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070638_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070742_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071537_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071953_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID072540_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072748_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID073543_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID074130_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID101212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102215_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102319_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID103114_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID103218_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID105120_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106435_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109132_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID109236_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID109964_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110211_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID110419_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112009_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112113_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID113012_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID114951_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID115122_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID115226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117128_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117232_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117752_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID119654_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID120837_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120941_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID121424_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID125644_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID129552_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID130943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID131634_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID135022_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID139970_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID150219_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150427_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150739_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150843_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID151430_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID153956_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID154023_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID156237_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID156341_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID157136_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID157240_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID158347_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159558_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159974_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID163126_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID163230_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID165236_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID167034_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169352_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID169456_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID171330_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179042_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179562_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID179666_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200106_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200210_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200314_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200938_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201525_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201733_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID202840_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204430_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204534_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID205641_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID207751_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID207855_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID208026_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID208962_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID211423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID211943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID215019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216126_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID216230_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216334_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID216646_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID216854_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217025_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217129_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217753_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217961_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID219239_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID220734_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID221321_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221841_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221945_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223639_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223743_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223847_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223951_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224122_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224746_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224850_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224954_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID225021_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: 54.75%

# %% [markdown]
# # Random Forest

# %%
predictions = rf_model.predict(test_data)  # Dự đoán giới tính trên dữ liệu kiểm tra

# In kết quả dự đoán và tên tệp tin tương ứng
for filename, label, prediction in zip(test_filenames, test_labels, predictions):
    print("File:", filename)
    print("Dự đoán giới tính:", prediction)
    print("--------------------")

accuracy = accuracy_score(test_labels, predictions)  # Tính độ chính xác bằng cách so sánh nhãn thực tế và nhãn dự đoán
print("Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: {:.2f}%".format(accuracy * 100))
# Out:
# File: ID000104_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002630_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002838_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID002942_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID004636_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005431_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID005535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID005639_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID008440_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID009443_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID009547_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID009859_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID010002_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013635_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID013843_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID014222_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014638_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID014950_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID015953_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID016020_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID016124_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID017127_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID018650_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019029_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID019341_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID019445_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID020212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID020732_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021527_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID021631_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021735_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID021943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID022218_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID022322_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID024744_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID053643_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID054230_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID054334_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID054438_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID057863_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID057967_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058242_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058346_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058762_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID058866_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID059973_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID061535_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID063645_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID064960_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID065131_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID065859_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID065963_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066030_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066134_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066238_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066446_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066550_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066654_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID066758_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID066862_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID067969_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068036_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068348_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068452_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068556_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID068660_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068764_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID068972_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID069975_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070014_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID070638_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID070742_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID071537_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID071953_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID072540_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID072748_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID073543_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID074130_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID101212_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102215_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102319_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID102423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID102943_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID103114_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID103218_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID105120_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID106435_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID109132_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109236_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID109964_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110211_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID110419_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID112009_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID112113_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID113012_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID114951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID115122_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID115226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117128_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID117232_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID117752_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID119654_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID120837_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID120941_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID121424_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID125644_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID129552_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID130943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID131634_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID135022_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID139970_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID150219_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150427_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150739_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID150843_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID151430_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID153956_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID154023_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID156237_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID156341_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID157136_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID157240_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID158347_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159558_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID159974_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID163126_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID163230_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID165236_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID167034_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169352_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID169456_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID171330_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179042_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179562_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID179666_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200106_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200210_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID200314_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID200938_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID201525_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID201733_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID202840_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204222_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID204430_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID204534_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID205641_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID207751_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID207855_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID208026_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID208962_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID211423_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID211943_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID215019_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216126_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216230_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID216334_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216646_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID216854_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217025_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID217129_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217753_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID217961_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID219239_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID220734_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221321_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID221841_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID221945_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223639_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223743_Walk2_0.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID223847_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID223951_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224122_Walk2_1.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224226_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224746_Walk2_0.csv
# Dự đoán giới tính: 0
# --------------------
# File: ID224850_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID224954_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# File: ID225021_Walk2_1.csv
# Dự đoán giới tính: 1
# --------------------
# Độ chính xác của mô hình Random Forest trên dữ liệu kiểm tra: 75.98%
