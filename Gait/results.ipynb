# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(30,121)

# %% [markdown]
# ## Linear

# %%
dataset_file_poly = './results_linear.csv'
dataset_linear = pd.read_csv(dataset_file_poly,skiprows=1, names=['predictions'])

predictions = dataset_linear['predictions']
plt.plot(t,predictions)

# %% [markdown]
# ## Poly

# %%
dataset_file_poly = './results_poly.csv'
dataset_poly = pd.read_csv(dataset_file_poly,skiprows=1, names=['predictions'])

predictions = dataset_poly['predictions']
plt.plot(t,predictions)

# %% [markdown]
# ## Rbf

# %%
dataset_file_poly = './results_rbf.csv'
dataset_rbf = pd.read_csv(dataset_file_poly,skiprows=1, names=['predictions'])

predictions = dataset_rbf['predictions']
plt.plot(t,predictions)

# %% [markdown]
# ## Sigmoid

# %%
dataset_file_poly = './results_sigmoid.csv'
dataset_sigmoid = pd.read_csv(dataset_file_poly,skiprows=1, names=['predictions'])

predictions = dataset_sigmoid['predictions']
plt.plot(t,predictions)

# %% [markdown]
# ## Random Forest

# %%
dataset_file_poly = './results_rf.csv'
dataset_rf = pd.read_csv(dataset_file_poly,skiprows=1, names=['predictions'])

t2 = range(30,1000,5)

predictions = dataset_rf['predictions']
plt.plot(t2,predictions)

# %% [markdown]
# ### n = 350

# %%
dataset_file_poly = './results_rf2.csv'
dataset_rf = pd.read_csv(dataset_file_poly,skiprows=1, names=['predictions'])

t3 = range(1,20)

predictions = dataset_rf['predictions']
plt.plot(t3,predictions)
